# %%
# ค่าเริ่มต้น (จะถูกเขียนทับโดยไฟล์แม่)
msg = "Default message"
file_index = 0

# %%
import datetime

# จำลองการทำงาน
print(f"--- เริ่มต้นการทำงานของไฟล์ลูกที่ {file_index} ---")
print(f"ข้อความที่ได้รับ: {msg}")
print(f"เวลาปัจจุบัน: {datetime.datetime.now()}")

# สมมติว่าเป็นส่วนที่จัดการ Google Sheet
print(f"กำลังบันทึกข้อมูลชุดที่ {file_index} ลง Google Sheet...")
print("✅ บันทึกสำเร็จ!")
# Out:
# --- เริ่มต้นการทำงานของไฟล์ลูกที่ 0 ---
# ข้อความที่ได้รับ: Default message
# เวลาปัจจุบัน: 2026-02-10 16:55:49.120127
# กำลังบันทึกข้อมูลชุดที่ 0 ลง Google Sheet...
# ✅ บันทึกสำเร็จ!
